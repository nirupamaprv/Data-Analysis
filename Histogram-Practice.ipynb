# %%
import pandas as pd
% matplotlib inline

# %%
df = pd.read_csv('ChicagoResults.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 271 entries, 0 to 270
# Data columns (total 7 columns):
# year          271 non-null int64
# city          271 non-null object
# country       271 non-null object
# avg_temp      271 non-null float64
# sevenDayMA    265 non-null float64
# FiveYearMA    267 non-null float64
# TenYearMA     262 non-null float64
# dtypes: float64(4), int64(1), object(2)
# memory usage: 14.9+ KB

# %%
df.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x111654d30>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x119cfae10>]], dtype=object)

# %%
df['avg_temp'].hist()

# %%
df['avg_temp'].plot(kind = 'hist')

# %%
df['year'].value_counts()
# Out:
# 2013    1
# 1827    1
# 1841    1
# 1840    1
# 1839    1
# 1838    1
# 1837    1
# 1836    1
# 1835    1
# 1834    1
# 1833    1
# 1832    1
# 1831    1
# 1830    1
# 1829    1
# 1828    1
# 1826    1
# 1843    1
# 1825    1
# 1824    1
# 1823    1
# 1822    1
# 1821    1
# 1820    1
# 1819    1
# 1818    1
# 1817    1
# 1816    1
# 1815    1
# 1814    1
#        ..
# 1942    1
# 1941    1
# 1940    1
# 1939    1
# 1938    1
# 1937    1
# 1936    1
# 1935    1
# 1934    1
# 1933    1
# 1932    1
# 1931    1
# 1930    1
# 1928    1
# 1913    1
# 1927    1
# 1926    1
# 1925    1
# 1924    1
# 1923    1
# 1922    1
# 1921    1
# 1920    1
# 1919    1
# 1918    1
# 1917    1
# 1916    1
# 1915    1
# 1914    1
# 1743    1
# Name: year, Length: 271, dtype: int64

# %%
df['year'].value_counts().plot(kind = 'bar')

# %%
df['year'].value_counts().plot(kind = 'pie')

# %%
df['year'].value_counts().plot(kind = 'pie', figsize = (5,5))

# %%
df_blog = pd.read_csv('WPCount.csv')
df_blog.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 254 entries, 0 to 253
# Data columns (total 2 columns):
# Home page / Archives    254 non-null object
# 2543                    254 non-null int64
# dtypes: int64(1), object(1)
# memory usage: 4.0+ KB

# %%
pd.plotting.scatter_matrix(df_blog)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x11e3e70f0>]], dtype=object)

# %%
pd.plotting.scatter_matrix(df_blog, figsize = (4,4))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x11e4029e8>]], dtype=object)

# %%
df_corr = pd.read_csv('CorrEff.csv')
df_corr.info()

#df.plot(x = , y = , kind = 'scatter')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 266 entries, 0 to 265
# Data columns (total 4 columns):
# year               264 non-null float64
# avg_temp_Chi       264 non-null float64
# year.1             264 non-null float64
# avg_temp_global    264 non-null float64
# dtypes: float64(4)
# memory usage: 8.4 KB

# %%
df_corr.plot(x = 'avg_temp_Chi', y = 'avg_temp_global', kind = 'scatter')

# %%
df.boxplot()
