# %% [markdown]
# # Exploring Data with Visuals Quiz
# Use the space below to explore `powerplant_data_edited.csv` to answer the quiz questions below.

# %%
# imports and load data
import pandas as pd
% matplotlib inline

# %%
df = pd.read_csv('powerplant_data_edited.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9568 entries, 0 to 9567
# Data columns (total 5 columns):
# Ambient Temperature    9568 non-null float64
# Exhaust Vacuum         9568 non-null float64
# Ambient Pressure       9568 non-null float64
# Relative Humidity      9568 non-null float64
# Energy Output          9568 non-null float64
# dtypes: float64(5)
# memory usage: 373.8 KB

# %%
# plot relationship between temperature and electrical output
df.plot(x = 'Ambient Temperature', y = 'Energy Output', kind = 'scatter')

# %%
# plot distribution of humidity
df['Relative Humidity'].hist()

# %%
# plot box plots for each variable
#pd.plotting.scatter_matrix(df)

# %%
df.boxplot()

# %%
df.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f32e0c44b00>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f32cca7b828>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f32c82a6a90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f32bfd34d30>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f32bfdb7d30>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f32bfdb7978>]], dtype=object)
